# %%
import pandas as pd

df = pd.read_csv("air_quality_model_ready.csv")

print(df.shape)
print(df.dtypes)
print(df.isnull().sum().sum())
df.head()
# Out:
# (8784, 27)
# PM2.5 (µg/m³)          float64
# PM10 (µg/m³)           float64
# NO (µg/m³)             float64
# NO2 (µg/m³)            float64
# NOx (ppb)              float64
# NH3 (µg/m³)            float64
# SO2 (µg/m³)            float64
# CO (mg/m³)             float64
# Ozone (µg/m³)          float64
# Benzene (µg/m³)        float64
# Toluene (µg/m³)        float64
# Xylene (µg/m³)         float64
# Eth-Benzene (µg/m³)    float64
# MP-Xylene (µg/m³)      float64
# AT (°C)                float64
# RH (%)                 float64
# WS (m/s)               float64
# WD (deg)               float64
# RF (mm)                float64
# TOT-RF (mm)            float64
# SR (W/mt2)             float64
# BP (mmHg)              float64
# VWS (m/s)              float64
# Month                  float64
# Hour                   float64
# Weekday                float64
# AQI_Label                int64
# dtype: object
# 0
#    PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# 0       0.758181      0.469185   -0.412348    -0.418832  -0.239623
# 1       0.734291      0.432318   -0.397986    -0.497807  -0.252630
# 2       0.676191      0.356462   -0.385910    -0.414993  -0.214215
# 3       0.648375      0.319123   -0.424424    -0.483548  -0.271081
# 4       0.618428      0.320931   -0.414959    -0.510970  -0.272896
#
#    NH3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  Ozone (µg/m³)  Benzene (µg/m³)  ...  \
# 0     0.398988    -0.687071    0.053854      -0.855273        -0.401137  ...
# 1     0.622702    -0.808447   -0.040602      -0.834750        -0.434677  ...
# 2     0.395217    -0.685014   -0.009117      -0.844006         0.219365  ...
# 3     0.620188    -0.954509   -0.056345      -0.851249         0.185824  ...
# 4     0.411556    -0.956566   -0.040602      -0.856883        -0.375981  ...
#
#    WD (deg)   RF (mm)  TOT-RF (mm)  SR (W/mt2)  BP (mmHg)  VWS (m/s)  \
# 0 -0.318858 -0.141275    -0.142726   -0.694085   1.882801   0.751086
# 1 -0.318858 -0.141275    -0.142726   -0.693736   1.878137   0.784631
# 2  0.122589 -0.141275    -0.142726   -0.692898   1.882801   0.751086
# 3  0.352559 -0.141275    -0.142726   -0.692689   1.876582   0.751086
# 4 -0.341144 -0.141275    -0.142726   -0.693038   1.856371   0.717541
#
#       Month      Hour   Weekday  AQI_Label
# 0 -1.597591 -1.661325 -1.490661          5
# 1 -1.597591 -1.516862 -1.490661          5
# 2 -1.597591 -1.372399 -1.490661          5
# 3 -1.597591 -1.227936 -1.490661          5
# 4 -1.597591 -1.083473 -1.490661          5
#
# [5 rows x 27 columns]

# %%
from sklearn.linear_model import LogisticRegression

X = df.drop(columns=['AQI_Label'])
y = df['AQI_Label']

model = LogisticRegression(max_iter=1000)
model.fit(X, y)

print("Model trained successfully")
# Out:
# Model trained successfully
